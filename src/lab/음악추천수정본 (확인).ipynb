# %%
import pandas as pd
import urllib.request
import csv
import matplotlib.pyplot as plt
import  platform
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from bs4 import BeautifulSoup

# %%
# while True :
#     print("가수명-곡명 형태로 입력 : ",end='')
#     target_singer, target_title = input().split('-')
#     url = 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=' +urllib.parse.quote_plus(target_singer +' '+target_title + ' 곡정보')
#     html = urllib.request.urlopen(url).read()
#     soup = BeautifulSoup(html, 'html.parser')
    
#     try :
#         target_album = soup.select('.info.txt_4 > .info_group')[1].text.split()[1]
#         target_genre = soup.select('.info.txt_4 > .info_group')[3].text.strip().split()[1]
#         target_days = soup.select('.info.txt_4 > .info_group')[2].text.strip().split()[1].replace('.','')
#         season = soup.select('.info.txt_4 > .info_group')[2].text.strip().split('.')[1]
#         if '03' <= season and season <= '05':
#             target_season = '봄'
#         elif '06' <= season and season <= '08':
#             target_season = '여름'
#         elif '09' <= season and season <= '11':
#             target_season = '가을'
#         else:
#             target_season = '겨울'
#         target_lyric = soup.select('.text.no_ellipsis.type_center._content_text')[0].get_text()
#         break
        
#     # 곡이 없거나 잘못 입력된 경우    
#     except :
#         print("가사가 없거나 잘못된 입력입니다. 다시 입력해 주세요")
#         pass
    
# print("장르 : " + target_genre + "\n" + "발매계절 : " + target_season)

# target_title_org = target_title.strip()
# target_singer_org = target_singer.strip()

# target_singer = target_singer.replace(' ','')
# target_title  = target_title.replace(' ','') 
# target_genre = target_genre.strip()
# target_season = target_season.strip()
# target_lyric = target_lyric.strip()
# Out:
# 가수명-곡명 형태로 입력 : 조관우-겨울이야기
# 장르 : 발라드(국내)
# 발매계절 : 겨울

# %%
# if flag == 1 :
    
# while True:
#     data = pd.read_csv('가사전처리수정본.csv', low_memory=False)
#     if stop == 1 :
#         break
    
#     # 사용자가 입력한 곳이 데이터 셋에 있는지 확인
#     for i in range(len(data[["제목","가수"]])) :
#         temp_title = str(data.loc[i][0]).replace(' ','')
#         temp_singer = str(data.loc[i][1]).replace(' ','')
#         if (target_title in temp_title) and (target_singer in temp_singer) :
#             target_genre = data.loc[i][2]
#             target_season = data.loc[i][6]
#             stop = 1
#             break
    
#     # 없다면, 입력한 곡 추가
#     if stop == 0 :
#         temp = [target_title,target_singer,target_genre,target_days,target_album,target_lyric,target_season]
#         with open('가사전처리수정본.csv','a',encoding='utf-8-sig',newline='') as f:
#             Writer = csv.writer(f)
#             Writer.writerow(temp)
#         stop = 1
# end = time.time()
# print(end - start)
# Out:
# 24.248034477233887

# %% [markdown]
# # data load
# <br><br>
# 1. 약 42,000개의 크롤링 된 데이터 셋 csv 파일 읽어오기
# <br><br>
# 2. 사용자의 input 부분 수정
#     - '0' 입력시 종료
#     - input 데이터 공백 제거
# <br><br>
# 3. csv에서 입력된 곡 정보찾기
#     - input data와 비교를 위해 data의 '제목','가사' replace를 이용하여 공백 제거
#     - 곡이 있다면, index를 가져오는 부분 수정
#     - 기존 : pd.Series(data.index, index=[data['제목'],data['가수']]).drop_duplicates()
#     - 수정 후 : pd.Series(data.index, index=[data['제목'].replace(' ',''), data['가수'].replace(' ','')]).drop_duplicates()
#
# <br><br>
# 4. 없다면 입력된 곡 가사 크롤링 후 기존 csv파일에 추가

# %%
import time
import pandas as pd
import urllib.request
import csv
import matplotlib.pyplot as plt
import  platform
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from bs4 import BeautifulSoup

start = time.time()
data = pd.read_csv('가사전처리수정본2.csv', low_memory=False)
stop = flag = 0

while True:
    print("가수명-곡명 형태로 입력 (종료시 0 입력) : ", end='')
    temp_input = input()

    # 종료 조건
    if temp_input == '0':
        stop = 1
        break

    try:
        target_singer = temp_input.split('-')[0].replace(' ', '')
        target_title = temp_input.split('-')[1].replace(' ', '')

        if len(target_singer) == 0 or len(target_title) == 0:
            print("가사가 없거나 잘못된 입력입니다. 다시 입력해 주세요.")
            continue

        df_and = data[(data['가수'].str.replace(' ','') == target_singer) & (data['제목'].str.replace(' ','') == target_title)]

        try:
            if len(df_and.index) > 0:
                print(1)
                # csv파일에 검색한 가수명과 곡명이 있는 경우

                indices = pd.Series(data.index, index=[data['제목'].replace(' ',''), data['가수'].replace(' ','')]).drop_duplicates()

                idx = indices[(target_title, target_singer)][0]

                target_genre = data['장르'].iloc[idx]
                target_season = data['계절'].iloc[idx]
                break

            else:
                print(2)
                # csv파일에 검색한 가수명과 곡명이 없는 경우

                url = 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=' + urllib.parse.quote_plus(
                    target_singer + ' ' + target_title + ' 곡정보')
                html = urllib.request.urlopen(url).read()
                soup = BeautifulSoup(html, 'html.parser')

                try:
                    # 입력한 곡 가사 크롤링
                    print(3)
                    title = soup.select_one('.area_text_title > ._text')
                    for i in title:
                        target_title = i
                    target_singer = soup.select('.info.txt_4 > .info_group')[0].text.strip().split()[1]
                    target_genre = soup.select('.info.txt_4 > .info_group')[3].text.strip().split()[1]
                    target_days = soup.select('.info.txt_4 > .info_group')[2].text.strip().split()[1].replace('.', '')
                    target_album = soup.select('.info.txt_4 > .info_group')[1].text.split()[1]
                    target_lyric = soup.select('.text.no_ellipsis.type_center._content_text')[0].get_text()
                    season = soup.select('.info.txt_4 > .info_group')[2].text.strip().split('.')[1]
                    if '03' <= season and season <= '05':
                        target_season = '봄'
                    elif '06' <= season and season <= '08':
                        target_season = '여름'
                    elif '09' <= season and season <= '11':
                        target_season = '가을'
                    else:
                        target_season = '겨울'
                    flag = 1
                    break

                except:
                    print(4)
                    # 곡이 없거나 잘못 입력된 경우
                    print("가사가 없거나 잘못된 입력입니다. 다시 입력해 주세요.")
                    continue

        except:
            print(5)
            print("가사가 없거나 잘못된 입력입니다. 다시 입력해 주세요.")
            continue

    # 곡이 없거나 잘못 입력된 경우
    except:
        print(6)
        print("가사가 없거나 잘못된 입력입니다. 다시 입력해 주세요.")
        continue

# 곡을 추가해야 하는 경우
if flag == 1:
    target_genre = target_genre.strip()
    target_season = target_season.strip()
    temp = [target_title, target_singer, target_genre, target_days, target_album, target_lyric, target_season]
    with open('가사전처리수정본2.csv', 'a', encoding='utf-8-sig', newline='') as f:
        Writer = csv.writer(f)
        Writer.writerow(temp)
if stop == 0:
    print("가수: " + target_singer + "\n" + "제목: " + target_title + "\n" + "장르: " + target_genre + "\n" + "발매계절: " + target_season + "\n")
    print("실행시간 : " + str(time.time() - start))
# Out:
# 가수명-곡명 형태로 입력 (종료시 0 입력) : 싸   이 - 어 땠   을 까
# 1
# C:\Users\ILIFO-104\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2894: PerformanceWarning: indexing past lexsort depth may impact performance.
#   result = self._run_cell(
# 가수: 싸이
# 제목: 어땠을까
# 장르: 댄스(국내)
# 발매계절: 여름
#
# 실행시간 : 18.398060083389282

# %%
if data['가사'].isnull().sum() :
    data['가사'] = data['가사'].fillna('')
else :
    print("결측값 없음")
# Out:
# 결측값 없음

# %% [markdown]
# ## data 중복찾기
# <br>
# 1.제목과 가수로 중복된 데이터 검색
# <BR>
# 2.중복된 곡의 정보 조회

# %%
df = pd.DataFrame(data, columns=['제목','가수']) 
df2 = df[df.duplicated(['제목','가수'], keep = False)]
df_sorted_by_values = df2.sort_values(by='제목' ,ascending=False)
df_sorted_by_values
# Out:
#                   제목    가수
# 8507              희야   이승철
# 16460             희야   이승철
# 16477             희야   이승철
# 11711            희망가   한대수
# 18718            희망가   한대수
# ...              ...   ...
# 4901   1994년 어느 늦은 밤   장혜진
# 11460       12월의 로망스  유리상자
# 14297       12월의 로망스  유리상자
# 14600            10월    모든
# 17505            10월    모든
#
# [1461 rows x 2 columns]

# %%
is_title_dup = data['제목'] == '희야'
title_dup = data[is_title_dup]
title_dup
# Out:
#        제목   가수    장르       발매일                                       앨범명  \
# 3342   희야  김태우   발라드  20150606                  불후의 명곡 - 전설을 노래하다 (이승철편)
# 5065   희야   부활   록메탈  20110620                                     Color
# 8507   희야  이승철   발라드  20051103             20th Anniversary Live In 2005
# 11237  희야  박일남  성인가요  20130805                          언제 오시나요 / 그리운 소식
# 15273  희야  하예나   발라드  20120423                            보이스 코리아 Part 3
# 16460  희야  이승철   록메탈  20080723                               He`s Coming
# 16477  희야  이승철   발라드  20160628  The Gold (Original Recording Remastered)
#
#                                                       가사  계절
# 3342   \n너는 나를 좋아했잖아\n너는 비록 싫다고 말해도\n나는 너의 마음알아\nit's...  여름
# 5065   \n너는 비록 싫다고 말해도 나는 너의 마음 알아\n\n사랑한다 말하고 떠나면 나의...  여름
# 8507   \n\n 나 좀 바라봐.\n너는 나를 좋아했잖아\n너는 비록 싫다고 말해도 나는 너...  가을
# 11237  \n희야 오- 희야\n지금 어디 갔나\n나를 가슴 아픈 나를 버리고\n어이 떠나갔나...  여름
# 15273  \n너는 비록 싫다고 말해도 나는 너의 마음 알아\n\n사랑한다 말하고 떠나면 나의...   봄
# 16460  \n너는 비록 싫다고 말해도 나는 너의 마음알아\n사랑한단 말하고 떠나면 나의 마음...  여름
# 16477  \n너는 나를 좋아했잖아 \n너는 비록 싫다고 말해도 \n나는 너의 마음 알아\n사...  여름

# %%
data.index
# Out:
# RangeIndex(start=0, stop=19999, step=1)

# %%
#data = data.head(20000)

# %%
# ngram_range = (1,2) 단어의 묶음을 1개부터 2개까지 설정
tfidf = TfidfVectorizer(stop_words='english',analyzer = 'word',  min_df=2, ngram_range = (2, 4), sublinear_tf=True)

# 가사에 대해서 tf-idf 수행
tfidf_matrix = tfidf.fit_transform(data['가사'])
print(tfidf_matrix.shape)

tfidf.fit(data['가사']) # 벡터라이저가 단어들을 학습합니다.
sorted(tfidf.vocabulary_.items()) # 단어사전을 정렬합니다. 
#tfidf.vocabulary_ # 벡터라이저가 학습한 단어사전을 출력합니다.
# Out:
# (19999, 294731)
# [('10 minute', 0),
#  ('1000번의 이름을', 1),
#  ('1000번의 이름을 불렀어', 2),
#  ('1000번의 이름을 불렀어 1000개의', 3),
#  ('1000일 동안', 4),
#  ('1000일 동안 매일', 5),
#  ('1000일 동안 매일 너의', 6),
#  ('100프로 동의해', 7),
#  ('100프로 동의해 너와의', 8),
#  ('100프로 동의해 너와의 이별이', 9),
#  ('100프로 한가한', 10),
#  ('100프로 한가한 남자가', 11),
#  ('100프로 한가한 남자가 돼줄게', 12),
#  ('10cm씩 멀어져', 13),
#  ('10cm씩 멀어져 가다', 14),
#  ('10cm씩 멀어져 가다 가끔씩은', 15),
#  ('10개월 매일', 16),
#  ('10개월 매일 보는', 17),
#  ('10개월 매일 보는 얼굴', 18),
#  ('10년이 지나도', 19),
#  ('10년이 지난', 20),
#  ('10분 내로', 21),
#  ('10분 내로 내게로', 22),
#  ('10분 내로 내게로 달려와요', 23),
#  ('10시 4분', 24),
#  ('1234 bubble', 25),
#  ('1234 bubble bubble', 26),
#  ('1234 bubble bubble sweet', 27),
#  ('12월에 그댈', 28),
#  ('12월에 그댈 만났지', 29),
#  ('12월의 아침을', 30),
#  ('12월의 아침을 여는', 31),
#  ('12월의 아침을 여는 베갯속', 32),
#  ('18 18', 33),
#  ('18 18 18', 34),
#  ('1974년의 봄을', 35),
#  ('1974년의 봄을 아직', 36),
#  ('1974년의 봄을 아직 기억한다', 37),
#  ('1994년 어느', 38),
#  ('1994년 어느 늦은', 39),
#  ('19살 섬색시가', 40),
#  ('19살 섬색시가 순정을', 41),
#  ('19살 섬색시가 순정을 바쳐', 42),
#  ('1st verse', 43),
#  ('1년도 버틸', 44),
#  ('1년도 버틸 거야', 45),
#  ('1년도 버틸 거야 일어나', 46),
#  ('1년되던날 내가', 47),
#  ('1년되던날 내가 선물한', 48),
#  ('1년되던날 내가 선물한 검지에', 49),
#  ('1년만 매일', 50),
#  ('1년만 매일 자연사를', 51),
#  ('1년만 매일 자연사를 꿈꾸며', 52),
#  ('1년을 기다렸어', 53),
#  ('1년을 기다렸어 오늘', 54),
#  ('1년을 기다렸어 오늘 그대', 55),
#  ('1년을 기다렸죠', 56),
#  ('1년을 기다렸죠 오늘은', 57),
#  ('1년을 기다렸죠 오늘은 당신의', 58),
#  ('1년을 돌려받기', 59),
#  ('1년을 돌려받기 위해', 60),
#  ('1년을 돌려받기 위해 내가', 61),
#  ('1번 반복', 62),
#  ('1분 1초', 63),
#  ('1분 1초가', 64),
#  ('1분 1초가 소중한', 65),
#  ('1분 1초도', 66),
#  ('1분만 지나면', 67),
#  ('1분만 지나면 나는', 68),
#  ('1분만 지나면 나는 가요', 69),
#  ('1억을 손목에', 70),
#  ('1억을 손목에 감은', 71),
#  ('1억을 손목에 감은 기분', 72),
#  ('1절 기분이', 73),
#  ('1절 기분이 좋아', 74),
#  ('1절 기분이 좋아 언제나', 75),
#  ('1절 매타', 76),
#  ('1절 매타 나찰', 77),
#  ('1절 사랑의', 78),
#  ('1절 왕십리', 79),
#  ('1초가 소중한', 80),
#  ('1초라도 생각할까', 81),
#  ('1초라도 잊을까요', 82),
#  ('1초라도 잊을까요 너무도', 83),
#  ('1초라도 잊을까요 너무도 먼길을', 84),
#  ('1초라도 잊을까요 눈물아', 85),
#  ('1초라도 잊을까요 눈물아 눈물아', 86),
#  ('22시 전에', 87),
#  ('22시 전에 들어가', 88),
#  ('22시 전에 들어가 간만에', 89),
#  ('22시 후엔', 90),
#  ('22시 후엔 전화', 91),
#  ('22시 후엔 전화 받지', 92),
#  ('24 day', 93),
#  ('24 hours', 94),
#  ('24시간 내겐', 95),
#  ('24시간 내겐 위한', 96),
#  ('24시간 내겐 위한 시간', 97),
#  ('24시간 사랑해', 98),
#  ('24시간 사랑해 오직', 99),
#  ('24시간 사랑해 오직 너를', 100),
#  ('2년 만이야', 101),
#  ('2년 만이야 참겠어', 102),
#  ('2년 만이야 참겠어 근무', 103),
#  ('2년 만이야 참겠어 제대하고', 104),
#  ('2년 반이란', 105),
#  ('2년 반이란 시간', 106),
#  ('2년 반이란 시간 너무나', 107),
#  ('2번 반복', 108),
#  ('2월의 마지막', 109),
#  ('2절 mc', 110),
#  ('2절 mc meta', 111),
#  ('2절 나찰', 112),
#  ('2절 너를', 113),
#  ('2절 너를 사랑해', 114),
#  ('2절 너를 사랑해 언제나', 115),
#  ('2절 매타', 116),
#  ('2절 매타 나찰', 117),
#  ('300원 손에', 118),
#  ('300원 손에 쥐면', 119),
#  ('300원 손에 쥐면 행복했던', 120),
#  ('30년 hanged', 121),
#  ('30년 hanged 아니고', 122),
#  ('30년 hanged 아니고 rewind', 123),
#  ('30분만 셔따', 124),
#  ('30분만 셔따 가자', 125),
#  ('30분만 셔따 가자 아줌마', 126),
#  ('3rd time', 127),
#  ('3교시 체육', 128),
#  ('3교시 체육 시간에', 129),
#  ('3교시 체육 시간에 너의', 130),
#  ('3년 안에', 131),
#  ('3년을 보내는', 132),
#  ('3년을 보내는 동안에도', 133),
#  ('3년을 보내는 동안에도 가끔씩', 134),
#  ('3사랑이었어 사랑이었어', 135),
#  ('3사랑이었어 사랑이었어 처음', 136),
#  ('3사랑이었어 사랑이었어 처음 느낀', 137),
#  ('3월에 태어난', 138),
#  ('3월에 태어난 당신의', 139),
#  ('3월에 태어난 당신의 생일을', 140),
#  ('3절 매타', 141),
#  ('3중 잠금하고', 142),
#  ('3중 잠금하고 그냥', 143),
#  ('3중 잠금하고 그냥 버려', 144),
#  ('4u 가려진', 145),
#  ('4u 가려진 길의', 146),
#  ('4u 가려진 길의 빛을', 147),
#  ('4월 1일', 148),
#  ('4월이 오면', 149),
#  ('5월 어느날', 150),
#  ('5월의 향기', 151),
#  ('6개월 시한부', 152),
#  ('6개월 시한부 인생', 153),
#  ('6개월 시한부 인생 그건', 154),
#  ('7년을 만났죠', 155),
#  ('7년을 만났죠 아무도', 156),
#  ('7년을 만났죠 아무도 우리가', 157),
#  ('845 이건', 158),
#  ('845 이건 절대', 159),
#  ('845 이건 절대 game', 160),
#  ('8분이 지나고', 161),
#  ('8분이 지나고 9분이', 162),
#  ('8분이 지나고 9분이 오네', 163),
#  ('8시 걸로', 164),
#  ('8시 걸로 마음', 165),
#  ('8시 걸로 마음 읽어', 166),
#  ('8월의 어느', 167),
#  ('93 taking', 168),
#  ('93 taking 우린', 169),
#  ('93 taking 우린 약하지', 170),
#  ('9분이 오네', 171),
#  ('9분이 오네 1분만', 172),
#  ('9분이 오네 1분만 지나면', 173),
#  ('abc 신나게', 174),
#  ('able blend', 175),
#  ('able blend life', 176),
#  ('able blend life know', 177),
#  ('able know', 178),
#  ('able know queen', 179),
#  ('able know queen hearts', 180),
#  ('accanto te', 181),
#  ('act like', 182),
#  ('act like know', 183),
#  ('actin like', 184),
#  ('adam eve', 185),
#  ('addio non', 186),
#  ('addio non voltarti', 187),
#  ('addio non voltarti se', 188),
#  ('addio spiegami', 189),
#  ('addio spiegami chi', 190),
#  ('addio spiegami chi vicino', 191),
#  ('admit shame', 192),
#  ('admit shame deny', 193),
#  ('admit shame deny lay', 194),
#  ('admit wrong', 195),
#  ('afraid cause', 196),
#  ('afraid know', 197),
#  ('afraid open', 198),
#  ('afraid open let', 199),
#  ('afraid open let love', 200),
#  ('agian needin', 201),
#  ('agian needin souls', 202),
#  ('ago 내가', 203),
#  ('ah ah', 204),
#  ('ah ah ah', 205),
#  ('ah ah ah ah', 206),
#  ('ah ah ah like', 207),
#  ('ah ah ah screamin', 208),
#  ('ah ah ah 미친듯', 209),
#  ('ah ah got', 210),
#  ('ah ah let', 211),
#  ('ah ah let break', 212),
#  ('ah ah like', 213),
#  ('ah ah like ah', 214),
#  ('ah ah oh', 215),
#  ('ah ah run', 216),
#  ('ah ah run ah', 217),
#  ('ah ah run 운동장', 218),
#  ('ah ah screamin', 219),
#  ('ah ah screamin ah', 220),
#  ('ah ah 미친듯', 221),
#  ('ah ah 미친듯 ah', 222),
#  ('ah baby', 223),
#  ('ah don', 224),
#  ('ah got', 225),
#  ('ah ha', 226),
#  ('ah let', 227),
#  ('ah let break', 228),
#  ('ah let break come', 229),
#  ('ah like', 230),
#  ('ah like ah', 231),
#  ('ah like ah ah', 232),
#  ('ah oh', 233),
#  ('ah oh oh', 234),
#  ('ah oh oh oh', 235),
#  ('ah run', 236),
#  ('ah run ah', 237),
#  ('ah run ah ah', 238),
#  ('ah run 운동장', 239),
#  ('ah run 운동장 한바퀴만', 240),
#  ('ah screamin', 241),
#  ('ah screamin ah', 242),
#  ('ah screamin ah ah', 243),
#  ('ah wanna', 244),
#  ('ah woo', 245),
#  ('ah ye', 246),
#  ('ah yeah', 247),
#  ('ah yeah 태사자', 248),
#  ('ah 감출', 249),
#  ('ah 그대', 250),
#  ('ah 그래', 251),
#  ('ah 내게', 252),
#  ('ah 너무', 253),
#  ('ah 더러워', 254),
#  ('ah 더러워 보여', 255),
#  ('ah 더러워 보여 계속', 256),
#  ('ah 말을', 257),
#  ('ah 말을 더듬어', 258),
#  ('ah 말을 더듬어 ah', 259),
#  ('ah 맘에', 260),
#  ('ah 머리가', 261),
#  ('ah 머리가 아파', 262),
#  ('ah 머리가 아파 ah', 263),
#  ('ah 미친', 264),
#  ('ah 미친 같아', 265),
#  ('ah 미친 같아 이런', 266),
#  ('ah 미친놈', 267),
#  ('ah 미친놈 같아', 268),
#  ('ah 미친놈 같아 쉬운', 269),
#  ('ah 미친듯', 270),
#  ('ah 미친듯 ah', 271),
#  ('ah 미친듯 ah ah', 272),
#  ('ah 보며', 273),
#  ('ah 보며 살짝', 274),
#  ('ah 보며 살짝 웃는', 275),
#  ('ah 사랑이', 276),
#  ('ah 숨도', 277),
#  ('ah 숨도 ah', 278),
#  ('ah 숨도 ah 보며', 279),
#  ('ah 숨도 ah 아픈데', 280),
#  ('ah 숨쉴', 281),
#  ('ah 숨쉴 있는', 282),
#  ('ah 숨쉴 있는 run', 283),
#  ('ah 식은땀이나', 284),
#  ('ah 식은땀이나 안녕', 285),
#  ('ah 식은땀이나 안녕 이건', 286),
#  ('ah 아픈데', 287),
#  ('ah 아픈데 웃고', 288),
#  ('ah 아픈데 웃고 있는', 289),
#  ('ah 우린', 290),
#  ('ah 이제', 291),
#  ('ain easy', 292),
#  ('ain funny', 293),
#  ('ain gettin', 294),
#  ('ain gettin younger', 295),
#  ('ain gettin younger pain', 296),
#  ('ain goin', 297),
#  ('ain gonna', 298),
#  ('ain got', 299),
#  ('ain got got', 300),
#  ('ain got guts', 301),
#  ('ain got nothin', 302),
#  ('ain got time', 303),
#  ('ain make', 304),
#  ('ain need', 305),
#  ('ain party', 306),
#  ('ain tears', 307),
#  ('ain tears eyes', 308),
#  ('air air', 309),
#  ('air breathe', 310),
#  ('air bright', 311),
#  ('air bright time', 312),
#  ('air bright time right', 313),
#  ('airplane mode', 314),
#  ('alegria voltou', 315),
#  ('alegria voltou tao', 316),
#  ('alegria voltou tao feliz', 317),
#  ('alexander mcqueen', 318),
#  ('alight hit', 319),
#  ('alight hit light', 320),
#  ('alight hit light amplifiers', 321),
#  ('alive alive', 322),
#  ('alive oh', 323),
#  ('alive want', 324),
#  ('alive 어제처럼', 325),
#  ('alive 어제처럼 오늘도', 326),
#  ('alive 어제처럼 오늘도 아무', 327),
#  ('alla tua', 328),
#  ('allnight 까맣게', 329),
#  ('allnight 까맣게 젖은', 330),
#  ('allnight 까맣게 젖은 너의', 331),
#  ('allontana da', 332),
#  ('allontana da qui', 333),
#  ('allontana da qui onda', 334),
#  ('alright alright', 335),
#  ('alright alright alright', 336),
#  ('alright alright ok', 337),
#  ('alright alright ok 너무', 338),
#  ('alright baby', 339),
#  ('alright girl', 340),
#  ('alright gonna', 341),
#  ('alright just', 342),
#  ('alright know', 343),
#  ('alright let', 344),
#  ('alright maybe', 345),
#  ('alright ok', 346),
#  ('alright ok 너무', 347),
#  ('alright ok 너무 걱정하지', 348),
#  ('alright okay', 349),
#  ('alright stay', 350),
#  ('alright tell', 351),
#  ('alright tonight', 352),
#  ('alright yeah', 353),
#  ('alright yeh', 354),
#  ('alright 가끔', 355),
#  ('alright 그렇게', 356),
#  ('alright 너의', 357),
#  ('alright 마음을', 358),
#  ('alright 모두', 359),
#  ('alright 모든', 360),
#  ('alright 세상에', 361),
#  ('alright 세상에 벽을', 362),
#  ('alright 세상에 벽을 쌓고', 363),
#  ('alright 연애하는', 364),
#  ('alright 연애하는 기분이란', 365),
#  ('alright 연애하는 기분이란 나는', 366),
#  ('alright 오늘', 367),
#  ('alright 정말', 368),
#  ('alright 정말 좋은', 369),
#  ('alright 정말 좋은 같아', 370),
#  ('alright 한걸음씩', 371),
#  ('alright 한걸음씩 happy', 372),
#  ('alright 한걸음씩 happy 너의', 373),
#  ('alright 함께', 374),
#  ('alway 사랑은', 375),
#  ('alway 사랑은 보이지가', 376),
#  ('alway 사랑은 보이지가 않는', 377),
#  ('amazing grace', 378),
#  ('amazing grace sweet', 379),
#  ('amazing grace sweet sound', 380),
#  ('amazing 나랑', 381),
#  ('amazing 나랑 amazing', 382),
#  ('amazing 나랑 amazing 어째', 383),
#  ('amazing 너랑', 384),
#  ('amazing 너랑 amazing', 385),
#  ('amazing 너랑 amazing 나랑', 386),
#  ('amazing 맘속에', 387),
#  ('amazing 맘속에 듣기조차', 388),
#  ('amazing 맘속에 듣기조차 싫었던', 389),
#  ('amazing 어째', 390),
#  ('amazing 어째 저째', 391),
#  ('amazing 어째 저째 남이', 392),
#  ('amera lo', 393),
#  ('amera lo sa', 394),
#  ('amera lo sa che', 395),
#  ('amor uma', 396),
#  ('amor 카니발의', 397),
#  ('amor 카니발의 아침', 398),
#  ('amor 카니발의 아침 아침', 399),
#  ('amore oer', 400),
#  ('amore oer quest', 401),
#  ('amore oer quest odissea', 402),
#  ('amplifiers tonight', 403),
#  ('amplifiers tonight night', 404),
#  ('amplifiers tonight night gonna', 405),
#  ('anche la', 406),
#  ('ancora che', 407),
#  ('ancora che non', 408),
#  ('ancora che non cura', 409),
#  ('andrai senza', 410),
#  ('andrai senza parole', 411),
#  ('andrai senza parole senza', 412),
#  ('angel angel', 413),
#  ('angel angel angel', 414),
#  ('angel angel angel angel', 415),
#  ('angel angel angel 말할거에요', 416),
#  ('angel angel 그냥', 417),
#  ('angel angel 그냥 먼저', 418),
#  ('angel angel 말할거에요', 419),
#  ('angel angel 말할거에요 내일은', 420),
#  ('angel angel 이젠', 421),
#  ('angel angel 이젠 내가', 422),
#  ('angel angel 정말', 423),
#  ('angel angel 정말 아무것도', 424),
#  ('angel sent', 425),
#  ('angel sent baby', 426),
#  ('angel sent baby 1절', 427),
#  ('angel 그냥', 428),
#  ('angel 그냥 먼저', 429),
#  ('angel 그냥 먼저 말해주면', 430),
#  ('angel 말할거에요', 431),
#  ('angel 말할거에요 내일은', 432),
#  ('angel 말할거에요 내일은 다시', 433),
#  ('angel 이젠', 434),
#  ('angel 이젠 내가', 435),
#  ('angel 이젠 내가 먼저', 436),
#  ('angel 정말', 437),
#  ('angel 정말 아무것도', 438),
#  ('angel 정말 아무것도 모르는', 439),
#  ('angels bells', 440),
#  ('angels bells candy', 441),
#  ('angels bells candy cane', 442),
#  ('angels voices', 443),
#  ('anime che', 444),
#  ('anime che sono', 445),
#  ('anime che sono sempre', 446),
#  ('annega tutto', 447),
#  ('annega tutto così', 448),
#  ('annega tutto così naufraghi', 449),
#  ('ano felicidad', 450),
#  ('ano felicidad wanna', 451),
#  ('ano felicidad wanna wish', 452),
#  ('anymore don', 453),
#  ('anymore don love', 454),
#  ('anymore don love anymore', 455),
#  ('anymore know', 456),
#  ('anymore want', 457),
#  ('ao coracao', 458),
#  ('ao coracao depois', 459),
#  ('ao coracao depois este', 460),
#  ('ao meu', 461),
#  ('ao meu coracao', 462),
#  ('ao meu coracao alegria', 463),
#  ('apart baby', 464),
#  ('apart baby 2년', 465),
#  ('apart baby 2년 만이야', 466),
#  ('apart baby just', 467),
#  ('apart baby just 2년', 468),
#  ('apart god', 469),
#  ('apart god sake', 470),
#  ('apart god sake long', 471),
#  ('apart hard', 472),
#  ('apart hard stay', 473),
#  ('apart hard stay years', 474),
#  ('apart oh', 475),
#  ('apart oh years', 476),
#  ('apart oh years apart', 477),
#  ('apart years', 478),
#  ('apart years apart', 479),
#  ('apart years apart god', 480),
#  ('appeared knocked', 481),
#  ('appeared knocked defence', 482),
#  ('appeared knocked defence touched', 483),
#  ('appeared soul', 484),
#  ('appeared soul felt', 485),
#  ('appeared soul felt worth', 486),
#  ('apple eyes', 487),
#  ('apple strudels', 488),
#  ('apple strudels doorbells', 489),
#  ('approach 사랑과', 490),
#  ('approach 사랑과 이별은', 491),
#  ('approach 사랑과 이별은 반복돼', 492),
#  ('aquaman baby', 493),
#  ('aquaman baby know', 494),
#  ('aquaman baby know waiting', 495),
#  ('aquaman baby oh', 496),
#  ('aquaman baby oh gonna', 497),
#  ('aquaman ll', 498),
#  ('aquaman ll deep', 499),
#  ('aquaman ll deep legs', 500),
#  ('aquaman ll surfing', 501),
#  ('aquaman ll surfing waves', 502),
#  ('aquaman make', 503),
#  ('aquaman make come', 504),
#  ('aquaman make come night', 505),
#  ('ara time', 506),
#  ('ara time love', 507),
#  ('ara 새빨간', 508),
#  ('ara 새빨간 장미처럼', 509),
#  ('ara 새빨간 장미처럼 가시같은', 510),
#  ('arms feel', 511),
#  ('arms hold', 512),
#  ('arms oh', 513),
#  ('arms till', 514),
#  ('arms till snow', 515),
#  ('arms till snow melts', 516),
#  ('arranged lovecity', 517),
#  ('arranged lovecity vocal', 518),
#  ('arranged vink', 519),
#  ('arranged vink rap', 520),
#  ('arranged vink rap eric', 521),
#  ('art coming', 522),
#  ('art coming straight', 523),
#  ('art coming straight heart', 524),
#  ('art truth', 525),
#  ('art truth truth', 526),
#  ('art truth truth art', 527),
#  ('asia got', 528),
#  ('asia got talent', 529),
#  ('asia got talent 여기', 530),
#  ('asked knew', 531),
#  ('asking year', 532),
#  ('asking year wanna', 533),
#  ('asking year wanna love', 534),
#  ('asking year wanna loved', 535),
#  ('ass im', 536),
#  ('assist good', 537),
#  ('assist good sound', 538),
#  ('assist good sound studio', 539),
#  ('atnt stopping', 540),
#  ('atnt stopping popping', 541),
#  ('atnt stopping popping hits', 542),
#  ('attacks forth', 543),
#  ('attacks forth flows', 544),
#  ('attacks forth flows yo', 545),
#  ('attendance chromosome', 546),
#  ('attention rest', 547),
#  ('attention rest intellect', 548),
#  ('attention rest intellect style', 549),
#  ('ave ave', 550),
#  ('ave maria', 551),
#  ('avvincina allontana', 552),
#  ('avvincina allontana da', 553),
#  ('avvincina allontana da qui', 554),
#  ('awake rise', 555),
#  ('awake rise sleep', 556),
#  ('awake rise sleep pretty', 557),
#  ('aware ra', 558),
#  ('aware ra ra', 559),
#  ('aware ra ra ra', 560),
#  ('aware 니가', 561),
#  ('aware 니가 줬던', 562),
#  ('aware 니가 줬던 반질', 563),
#  ('aware 산뜻하게', 564),
#  ('aware 산뜻하게 머릴', 565),
#  ('aware 산뜻하게 머릴 바꾸고', 566),
#  ('away away', 567),
#  ('away away away', 568),
#  ('away away oh', 569),
#  ('away baby', 570),
#  ('away better', 571),
#  ('away cause', 572),
#  ('away cold', 573),
#  ('away come', 574),
#  ('away day', 575),
#  ('away day night', 576),
#  ('away day night dreaming', 577),
#  ('away days', 578),
#  ('away don', 579),
#  ('away don away', 580),
#  ('away don know', 581),
#  ('away fade', 582),
#  ('away fade away', 583),
#  ('away far', 584),
#  ('away far away', 585),
#  ('away far away far', 586),
#  ('away far away 아주', 587),
#  ('away feel', 588),
#  ('away finally', 589),
#  ('away fly', 590),
#  ('away fly away', 591),
#  ('away fly fly', 592),
#  ('away fly fly away', 593),
#  ('away gonna', 594),
#  ('away good', 595),
#  ('away heart', 596),
#  ('away hold', 597),
#  ('away jingle', 598),
#  ('away jingle bell', 599),
#  ('away jingle bell time', 600),
#  ('away just', 601),
#  ('away know', 602),
#  ('away let', 603),
#  ('away life', 604),
#  ('away like', 605),
#  ('away ll', 606),
#  ('away lonely', 607),
#  ('away love', 608),
#  ('away love fly', 609),
#  ('away love fly away', 610),
#  ('away need', 611),
#  ('away oh', 612),
#  ('away oh better', 613),
#  ('away oh better run', 614),
#  ('away oh oh', 615),
#  ('away oh oh oh', 616),
#  ('away right', 617),
#  ('away run', 618),
#  ('away run away', 619),
#  ('away say', 620),
#  ('away sing', 621),
#  ('away sunshine', 622),
#  ('away tell', 623),
#  ('away time', 624),
#  ('away turn', 625),
#  ('away wanna', 626),
#  ('away want', 627),
#  ('away way', 628),
#  ('away 곁에', 629),
#  ('away 곁에 fly', 630),
#  ('away 곁에 fly away', 631),
#  ('away 곳으로', 632),
#  ('away 곳으로 내가', 633),
#  ('away 곳으로 내가 아닌', 634),
#  ('away 곳으로 내가 없는', 635),
#  ('away 그대', 636),
#  ('away 그대와', 637),
#  ('away 그대와 함께', 638),
#  ('away 그대와 함께 영원한', 639),
#  ('away 그렇게', 640),
#  ('away 그렇게 fly', 641),
#  ('away 그렇게 fly away', 642),
#  ('away 내가', 643),
#  ('away 너를', 644),
#  ('away 너무', 645),
#  ('away 너의', 646),
#  ('away 숨쉴', 647),
#  ('away 숨쉴 있는', 648),
#  ('away 숨쉴 있는 ah', 649),
#  ('away 숨쉴 있는 run', 650),
#  ('away 아주', 651),
#  ('away 아주 멀리', 652),
#  ('away 아주 멀리 open', 653),
#  ('away 아픈', 654),
#  ('away 아픈 눈물', 655),
#  ('away 아픈 눈물 없는', 656),
#  ('away 우리를', 657),
#  ('away 우리를 위한', 658),
#  ('away 우리를 위한 사랑', 659),
#  ('away 이러는지', 660),
#  ('away 이러는지 쉽게', 661),
#  ('away 이러는지 쉽게 잊었다', 662),
#  ('away 이미', 663),
#  ('away 이미 여기', 664),
#  ('away 이미 여기 없는데', 665),
#  ('away 이제', 666),
#  ('away 좁아진', 667),
#  ('away 좁아진 기로에', 668),
#  ('away 좁아진 기로에 날갤', 669),
#  ('away 햇살은', 670),
#  ('away 햇살은 눈부신데', 671),
#  ('away 햇살은 눈부신데 맘은', 672),
#  ('away 흰눈이', 673),
#  ('away 흰눈이 내리는', 674),
#  ('away 흰눈이 내리는 내게와', 675),
#  ('awhile raise', 676),
#  ('awhile raise stand', 677),
#  ('awhile raise stand mountains', 678),
#  ('ay ay', 679),
#  ('ay ay ay', 680),
#  ('ay ay ay ay', 681),
#  ('ay girl', 682),
#  ('ay yo', 683),
#  ('ay 네게', 684),
#  ('aye 시간은', 685),
#  ('aye 시간은 금이', 686),
#  ('aye 시간은 금이 갖네', 687),
#  ('a라는 사람도', 688),
#  ('a라는 사람도 사랑하고', 689),
#  ('a라는 사람도 사랑하고 b라는', 690),
#  ('ba ba', 691),
#  ('ba rah', 692),
#  ('ba rah ppa', 693),
#  ('ba rah ppa rah', 694),
#  ('ba rah 노래', 695),
#  ('ba rah 노래 부르고', 696),
#  ('ba rah 언제나', 697),
#  ('ba rah 언제나 기억해', 698),
#  ('ba rah 풍경을', 699),
#  ('ba rah 풍경을 지나', 700),
#  ('ba_by 사랑을', 701),
#  ('ba_by 사랑을 그대에게', 702),
#  ('ba_by 사랑을 그대에게 oh', 703),
#  ('babe babe', 704),
#  ('babe babe babe', 705),
#  ('babe babe babe babe', 706),
#  ('babe babe 눈물이', 707),
#  ('babe babe 눈물이 떨어져', 708),
#  ('babe babe 다신', 709),
#  ('babe babe 다신 없어', 710),
#  ('babe babe 심장이', 711),
#  ('babe babe 심장이 떨어져', 712),
#  ('babe babe 어떠니', 713),
#  ('babe babe 어떠니 yeah', 714),
#  ('babe babe 이리', 715),
#  ('babe babe 이리 연락', 716),
#  ('babe baby', 717),
#  ('babe come', 718),
#  ('babe don', 719),
#  ('babe everyday', 720),
#  ('babe know', 721),
#  ('babe lady', 722),
#  ('babe let', 723),
#  ('babe oh', 724),
#  ('babe outro', 725),
#  ('babe say', 726),
#  ('babe tell', 727),
#  ('babe wanna', 728),
#  ('babe wanna know', 729),
#  ('babe wanna know taste', 730),
#  ('babe 나를', 731),
#  ('babe 내게', 732),
#  ('babe 너무', 733),
#  ('babe 너와', 734),
#  ('babe 눈물이', 735),
#  ('babe 눈물이 떨어져', 736),
#  ('babe 니가', 737),
#  ('babe 니가 너무', 738),
#  ('babe 다신', 739),
#  ('babe 다신 없어', 740),
#  ('babe 다신 없어 babe', 741),
#  ('babe 심장이', 742),
#  ('babe 심장이 떨어져', 743),
#  ('babe 심장이 떨어져 이거였어', 744),
#  ('babe 아직', 745),
#  ('babe 어떠니', 746),
#  ('babe 어떠니 yeah', 747),
#  ('babe 어떠니 yeah 손을', 748),
#  ('babe 왠지', 749),
#  ('babe 이건', 750),
#  ('babe 이리', 751),
#  ('babe 이리 연락', 752),
#  ('babe 이리 연락 없지', 753),
#  ('babe 이젠', 754),
#  ('babe 지금', 755),
#  ('baby 1절', 756),
#  ('baby 1절 기분이', 757),
#  ('baby 1절 기분이 좋아', 758),
#  ('baby 2년', 759),
#  ('baby 2년 만이야', 760),
#  ('baby 2년 만이야 참겠어', 761),
#  ('baby ah', 762),
#  ('baby alright', 763),
#  ('baby away', 764),
#  ('baby babe', 765),
#  ('baby baby', 766),
#  ('baby baby baby', 767),
#  ('baby baby baby baby', 768),
#  ('baby baby baby don', 769),
#  ('baby baby baby girl', 770),
#  ('baby baby baby love', 771),
#  ('baby baby baby 사랑이', 772),
#  ('baby baby come', 773),
#  ('baby baby don', 774),
#  ('baby baby girl', 775),
#  ('baby baby just', 776),
#  ('baby baby lady', 777),
#  ('baby baby love', 778),
#  ('baby baby love baby', 779),
#  ('baby baby oh', 780),
#  ('baby baby oh baby', 781),
#  ('baby baby want', 782),
#  ('baby baby woo', 783),
#  ('baby baby 그대', 784),
#  ('baby baby 너의', 785),
#  ('baby baby 마음에서', 786),
#  ('baby baby 마음에서 일등', 787),
#  ('baby baby 사랑이', 788),
#  ('baby baby 사랑한다고', 789),
#  ('baby baby 욕심이', 790),
#  ('baby baby 욕심이 지나친', 791),
#  ('baby bad', 792),
#  ('baby beautiful', 793),
#  ('baby beautiful baby', 794),
#  ('baby beautiful baby wonderful', 795),
#  ('baby blame', 796),
#  ('baby blame brought', 797),
#  ('baby blame brought rain', 798),
#  ('baby blind', 799),
#  ('baby blind love', 800),
#  ('baby boo', 801),
#  ('baby boo girl', 802),
#  ('baby boo girl ride', 803),
#  ('baby boy', 804),
#  ('baby boy don', 805),
#  ('baby break', 806),
#  ('baby bring', 807),
#  ('baby change', 808),
#  ('baby check', 809),
#  ('baby chorus', 810),
#  ('baby come', 811),
#  ('baby come baby', 812),
#  ('baby come come', 813),
#  ('baby come come baby', 814),
#  ('baby come just', 815),
#  ('baby cool', 816),
#  ('baby crazy', 817),
#  ('baby day', 818),
#  ('baby day day', 819),
#  ('baby don', 820),
#  ('baby don away', 821),
#  ('baby don baby', 822),
#  ('baby don baby don', 823),
#  ('baby don forget', 824),
#  ('baby don know', 825),
#  ('baby don let', 826),
#  ('baby don need', 827),
#  ('baby don oh', 828),
#  ('baby don scared', 829),
#  ('baby don scared don', 830),
#  ('baby don stop', 831),
#  ('baby don wanna', 832),
#  ('baby don worry', 833),
#  ('baby don 이제', 834),
#  ('baby drive', 835),
#  ('baby drive crazy', 836),
#  ('baby eh', 837),
#  ('baby everyday', 838),
#  ('baby falling', 839),
#  ('baby falling love', 840),
#  ('baby feel', 841),
#  ('baby feels', 842),
#  ('baby fly', 843),
#  ('baby follow', 844),
#  ('baby forever', 845),
#  ('baby girl', 846),
#  ('baby girl baby', 847),
#  ('baby girl baby girl', 848),
#  ('baby girl check', 849),
#  ('baby girl check yes', 850),
#  ('baby girl girl', 851),
#  ('baby girl girl baby', 852),
#  ('baby girl know', 853),
#  ('baby girl know mean', 854),
#  ('baby girl let', 855),
#  ('baby girl lets', 856),
#  ('baby girl like', 857),
#  ('baby girl like job', 858),
#  ('baby girl love', 859),
#  ('baby girl oh', 860),
#  ('baby going', 861),
#  ('baby going crazy', 862),
#  ('baby gonna', 863),
#  ('baby gonna kiss', 864),
#  ('baby gonna kiss 사랑해', 865),
#  ('baby gonna love', 866),
#  ('baby gonna love 그대', 867),
#  ('baby gonna make', 868),
#  ('baby gonna make paradise', 869),
#  ('baby good', 870),
#  ('baby good luck', 871),
#  ('baby good night', 872),
#  ('baby goodnight', 873),
#  ('baby got', 874),
#  ('baby got girl', 875),
#  ('baby got girl girl', 876),
#  ('baby gotta', 877),
#  ('baby heart', 878),
#  ('baby heart baby', 879),
#  ('baby hello', 880),
#  ('baby hello hello', 881),
#  ('baby hey', 882),
#  ('baby hey baby', 883),
#  ('baby hey oh', 884),
#  ('baby hey oh baby', 885),
#  ('baby hey 세상에', 886),
#  ('baby hey 세상에 있긴', 887),
#  ('baby hold', 888),
#  ('baby just', 889),
#  ('baby just 2년', 890),
#  ('baby just 2년 만이야', 891),
#  ('baby just hold', 892),
#  ('baby just hold tight', 893),
#  ('baby just just', 894),
#  ('baby just wanna', 895),
#  ('baby just wanna know', 896),
#  ('baby just want', 897),
#  ('baby kiss', 898),
#  ('baby kiss darling', 899),
#  ('baby know', 900),
#  ('baby know know', 901),
#  ('baby know love', 902),
#  ('baby know waiting', 903),
#  ('baby know waiting hero', 904),
#  ('baby lady', 905),
#  ('baby leave', 906),
#  ('baby left', 907),
#  ('baby left oh', 908),
#  ('baby left oh long', 909),
#  ('baby let', 910),
#  ('baby let love', 911),
#  ('baby lie', 912),
#  ('baby lie lie', 913),
#  ('baby like', 914),
#  ('baby listen', 915),
#  ('baby listen let', 916),
#  ('baby listen let love', 917),
#  ('baby little', 918),
#  ('baby ll', 919),
#  ('baby ll alright', 920),
#  ('baby ll underwater', 921),
#  ('baby ll underwater girl', 922),
#  ('baby look', 923),
#  ('baby look eyes', 924),
#  ('baby look eyes 슬픔에', 925),
#  ('baby looking', 926),
#  ('baby love', 927),
#  ('baby love baby', 928),
#  ('baby love baby love', 929),
#  ('baby love baby need', 930),
#  ('baby love come', 931),
#  ('baby love don', 932),
#  ('baby love don say', 933),
#  ('baby love love', 934),
#  ('baby love love baby', 935),
#  ('baby love love love', 936),
#  ('baby love love 너를', 937),
#  ('baby love need', 938),
#  ('baby love tonight', 939),
#  ('baby love 사랑은', 940),
#  ('baby love 이젠', 941),
#  ('baby loving', 942),
#  ('baby loving woo', 943),
#  ('baby loving woo 그댄', 944),
#  ('baby ma', 945),
#  ('baby make', 946),
#  ('baby make better', 947),
#  ('baby make feel', 948),
#  ('baby make paradise', 949),
#  ('baby miss', 950),
#  ('baby miss miss', 951),
#  ('baby missing', 952),
#  ('baby need', 953),
#  ('baby need baby', 954),
#  ('baby need love', 955),
#  ('baby need love baby', 956),
#  ('baby need want', 957),
#  ('baby night', 958),
#  ('baby oh', 959),
#  ('baby oh baby', 960),
#  ('baby oh baby oh', 961),
#  ('baby oh gonna', 962),
#  ('baby oh gonna lost', 963),
#  ('baby oh love', 964),
#  ('baby oh oh', 965),
#  ('baby oh oh oh', 966),
#  ('baby ok', 967),
#  ('baby ooh', 968),
#  ('baby party', 969),
#  ('baby pop', 970),
#  ('baby pop pop', 971),
#  ('baby pop pop pop', 972),
#  ('baby rap', 973),
#  ('baby remember', 974),
#  ('baby right', 975),
#  ('baby right baby', 976),
#  ('baby right right', 977),
#  ('baby say', 978),
#  ('baby saying', 979),
#  ('baby sexy', 980),
#  ('baby sexy lady', 981),
#  ('baby shake', 982),
#  ('baby shark', 983),
#  ('baby shark doo', 984),
#  ('baby shark doo doo', 985),
#  ('baby shark mommy', 986),
#  ('baby shark mommy shark', 987),
#  ('baby sing', 988),
#  ('baby slow', 989),
#  ('baby sorry', 990),
#  ('baby sorry baby', 991),
#  ('baby sorry baby sorry', 992),
#  ('baby sorry sorry', 993),
#  ('baby sorry sorry sorry', 994),
#  ('baby stay', 995),
#  ('baby stay baby', 996),
#  ('baby step', 997),
#  ('baby stop', 998),
#  ('baby story', 999),
#  ...]

# %% [markdown]
# ## 코사인 유사도 실행

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %% [markdown]
# ## 유사곡 추천
# 1.사용자가 입력한 곡을 기준으로 장르, 발매계절이 같은 순으로 출력
# <br>
# 2.장르가 같은것이 없다면, 발매계절이 같은 순으로 출력

# %%
def get_recommendations(title, singer, genre, season, cosine_sim=cosine_sim):
    # 선택한 음악의 가수, 제목으로부터 해당되는 인덱스를 받아옵니다. 이제 선택한 음악를 가지고 연산할 수 있습니다.
    #idx = indices[title]
    idx = indices[(title, singer)][0]
    # 모든 음악에 대해서 해당 음악과의 유사도를 구합니다.
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # 유사도에 따라 음악들을 정렬합니다.
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # 가장 유사한 1000개의 음악을 받아옵니다.
    sim_scores = sim_scores[1:1001]

    #코사인값은 두 벡터의 방향이 완전히 같을 경우 1, 90°의 각을 이룰 경우 0, 180°로 완전히 반대 방향인 경우 -1의 값을 갖음
    #print(sim_scores)
    
    # 가장 유사한 1000개의 음악의 인덱스를 받아옵니다.
    movie_indices = [i[0] for i in sim_scores]

    # 가장 유사한 10개의 곡 출력
    num = 0
    for i in range(len(movie_indices)) :
        if num == 10 :
            break
        if float == type(data['장르'].iloc[movie_indices[i]]):
            continue
        if (data['장르'].iloc[movie_indices[i]] not in genre) :
            continue
        if(data['계절'].iloc[movie_indices[i]] != season) :
            continue
        num += 1
        a = data['가수'].iloc[movie_indices[i]] 
        b = data['제목'].iloc[movie_indices[i]]
        c = data['장르'].iloc[movie_indices[i]]
        d = data['계절'].iloc[movie_indices[i]]
        print(a+'-'+b+' ('+c+'), '+d+'발매') 
    
    if num < 10 :
        for i in range(len(movie_indices)) :
            if num == 10 :
                break
            if (data['계절'].iloc[movie_indices[i]] != season) :
                continue
            num += 1
            a = data['가수'].iloc[movie_indices[i]] 
            b = data['제목'].iloc[movie_indices[i]]
            c = data['장르'].iloc[movie_indices[i]]
            d = data['계절'].iloc[movie_indices[i]]
            print(a+'-'+b+' ('+c+'), '+d+'발매')

# %%
get_recommendations(target_title, target_singer, target_genre, target_season)
# Out:
# C:\Users\ILIFO-104\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2940: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return runner(coro)
# 자두-땡큐베뤼머취 (댄스), 여름발매
# 신혜성-Ex-Mind (댄스), 여름발매
# 손담비-dB Rider (댄스), 여름발매
# 유키스-Te Amo (댄스), 여름발매
# 김범수-외톨이야 (씨엔블루) (댄스), 여름발매
# 디유닛-기념일 (댄스), 여름발매
# 김현정-니가 사람이니! (댄스), 여름발매
# 히스토리-태양은 없다 (댄스), 여름발매
# 유키스-Believe (댄스), 여름발매
# 원투-둥글둥글 (댄스), 여름발매

# %% [markdown]
# ## ngram_range = 2~4로 선정
# <br>
# 아래 nrgam_range에 따른 결과를 보면, 1~2를 제외한 나머지의 결과는 동일
# <br>
# 가사의 경우 1개의 단어보다 2개의 단어가 의미를 갖는 경우가 많다고 생각
#
# 1~2 : 19997,210240
#
# 천명훈-정글 (댄스), 가을발매
# 크리스티나-Pay Day (댄스), 가을발매
# 바나나 보트-부비 Party (댄스), 가을발매
# 슈퍼걸-토요일 밤에 (댄스), 가을발매
# 투포케이-빨리와 (댄스), 가을발매
# 장우혁-Scream (댄스), 가을발매
# 원더보이즈-신난다 신나 (댄스), 가을발매
# 손호영-해피 바이러스 (댄스), 가을발매
# 탑독-비가 와서 그래 (댄스), 가을발매
#
# 1~4 : 19997,360352
#
# 천명훈-정글 (댄스), 가을발매
# 크리스티나-Pay Day (댄스), 가을발매
# 엔소닉-Run & Run (댄스), 가을발매
# 거북이-사계 (댄스), 가을발매
# 빅스타-왜이래 (댄스), 가을발매
# 김완선, 용준형-Be Quiet (댄스), 가을발매
# 양파-뱀파이어 (댄스), 가을발매
# 유승준-Paradise (댄스), 가을발매
# 별-비밀하나 (댄스), 가을발매
# 인디고-그 누구보다 더 (댄스), 가을발매
#
# 1~5 : 19997,425464
#
# 천명훈-정글 (댄스), 가을발매
# 크리스티나-Pay Day (댄스), 가을발매
# 엔소닉-Run & Run (댄스), 가을발매
# 거북이-사계 (댄스), 가을발매
# 빅스타-왜이래 (댄스), 가을발매
# 김완선, 용준형-Be Quiet (댄스), 가을발매
# 양파-뱀파이어 (댄스), 가을발매
# 유승준-Paradise (댄스), 가을발매
# 별-비밀하나 (댄스), 가을발매
# 인디고-그 누구보다 더 (댄스), 가을발매
#
#
# 2~4 : 19997,294707
#
# 천명훈-정글 (댄스), 가을발매
# 크리스티나-Pay Day (댄스), 가을발매
# 엔소닉-Run & Run (댄스), 가을발매
# 거북이-사계 (댄스), 가을발매
# 빅스타-왜이래 (댄스), 가을발매
# 김완선, 용준형-Be Quiet (댄스), 가을발매
# 양파-뱀파이어 (댄스), 가을발매
# 유승준-Paradise (댄스), 가을발매
# 별-비밀하나 (댄스), 가을발매
# 인디고-그 누구보다 더 (댄스), 가을발매
#
# 2~5 : 19997,359819
#
# 천명훈-정글 (댄스), 가을발매
# 크리스티나-Pay Day (댄스), 가을발매
# 엔소닉-Run & Run (댄스), 가을발매
# 거북이-사계 (댄스), 가을발매
# 빅스타-왜이래 (댄스), 가을발매
# 김완선, 용준형-Be Quiet (댄스), 가을발매
# 양파-뱀파이어 (댄스), 가을발매
# 유승준-Paradise (댄스), 가을발매
# 별-비밀하나 (댄스), 가을발매
# 인디고-그 누구보다 더 (댄스), 가을발매
